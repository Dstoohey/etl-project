# %%
#import dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd
import os
from sqlalchemy import create_engine

# %%
# URL of page to be scraped
#https://magicseaweed.com/Deal-Surf-Report/822/

# %%
#used the pandas read html method to convert the html to a dataframe

df = pd.read_html('https://magicseaweed.com/Deal-Surf-Report/822/')
len(df)
# Out:
# 17

# %%
df[0]
# Out:
#       0       1        2
# 0   Low  1:29AM   -0.1ft
# 1  High  7:43AM   4.85ft
# 2   Low  1:56PM  -0.33ft
# 3  High  8:05PM   4.36ft

# %%
df[1]
# Out:
#              0       1
# 0  First Light  6:07AM
# 1      Sunrise  6:35AM
# 2       Sunset  5:43PM
# 3   Last Light  6:10PM

# %%
df[2]
# Out:
#        Unnamed: 0          Surf  Swell Rating Primary Swell Primary Swell.1  \
# 0    Monday 02/24  Monday 02/24  Monday 02/24  Monday 02/24    Monday 02/24
# 1            12am         1-2ft           NaN         1.3ft             10s
# 2             3am         1-2ft           NaN         1.3ft             10s
# 3             6am         1-2ft           NaN         1.3ft             10s
# 4             9am         1-2ft           NaN         1.3ft             10s
# ..            ...           ...           ...           ...             ...
# 121          High       11:49PM         4.1ft           NaN             NaN
# 122   First Light        5:58AM           NaN           NaN             NaN
# 123       Sunrise        6:26AM           NaN           NaN             NaN
# 124        Sunset        5:50PM           NaN           NaN             NaN
# 125    Last Light        6:17PM           NaN           NaN             NaN
#
# ...

# %%
FridayWaves_df = df[2]

# %%
null_columns=FridayWaves_df.columns[FridayWaves_df.isnull().any()]

# %%
FridayWaves_df[null_columns].isnull().sum()
# Out:
# Swell Rating          84
# Primary Swell         56
# Primary Swell.1       56
# Primary Swell.2      112
# Secondary Swell       58
# Secondary Swell.1     58
# Secondary Swell.2    112
# Secondary Swell.3     79
# Secondary Swell.4     79
# Secondary Swell.5    112
# Wind                  56
# Wind.1               112
# Weather              112
# Weather.1             56
# Prob.                 56
# Unnamed: 17          112
# Unnamed: 18          112
# Unnamed: 19          112
# Unnamed: 20          112
# Unnamed: 21          112
# dtype: int64

# %%
FridayWaves_df=FridayWaves_df.dropna()
FridayWaves_df
# Out:
#                                             Unnamed: 0  \
# 0                                         Monday 02/24
# 9    Tide and daylight times for Belmar, Atlantic O...
# 18                                       Tuesday 02/25
# 27   Tide and daylight times for Belmar, Atlantic O...
# 36                                     Wednesday 02/26
# 45   Tide and daylight times for Belmar, Atlantic O...
# 54                                      Thursday 02/27
# 63   Tide and daylight times for Belmar, Atlantic O...
# 72                                        Friday 02/28
# 81   Tide and daylight times for Belmar, Atlantic O...
# 90                                      Saturday 02/29
# 99   Tide and daylight times for Belmar, Atlantic O...
# 108                                       Sunday 03/01
# 117  Tide and daylight times for Belmar, Atlantic O...
#
#                                                   Surf  \
# 0                                         Monday 02/24
# ...

# %%
FridayWaves_df.reset_index()
# Out:
#     index                                         Unnamed: 0  \
# 0       0                                       Monday 02/24
# 1       9  Tide and daylight times for Belmar, Atlantic O...
# 2      18                                      Tuesday 02/25
# 3      27  Tide and daylight times for Belmar, Atlantic O...
# 4      36                                    Wednesday 02/26
# 5      45  Tide and daylight times for Belmar, Atlantic O...
# 6      54                                     Thursday 02/27
# 7      63  Tide and daylight times for Belmar, Atlantic O...
# 8      72                                       Friday 02/28
# 9      81  Tide and daylight times for Belmar, Atlantic O...
# 10     90                                     Saturday 02/29
# 11     99  Tide and daylight times for Belmar, Atlantic O...
# 12    108                                       Sunday 03/01
# 13    117  Tide and daylight times for Belmar, Atlantic O...
#
# ...

# %%
FridayWaves_df.describe()
# Out:
#                                                Unnamed: 0  \
# count                                                  14
# unique                                                 14
# top     Tide and daylight times for Belmar, Atlantic O...
# freq                                                    1
#
#                                                      Surf  \
# count                                                  14
# unique                                                 14
# top     Tide and daylight times for Belmar, Atlantic O...
# freq                                                    1
#
#                                              Swell Rating  \
# count                                                  14
# unique                                                 14
# top     Tide and daylight times for Belmar, Atlantic O...
# freq                                                    1
#
#                                             Primary Swell  \
# ...

# %%
#import and read csv on well being and health data
#is there some correlation between surfing and well being?

# %%
healthySurfing = pd.read_csv("wellbeing-statistics-2018-csv/wellbeing statistics 2018.csv")
healthySurfing = healthySurfing.reset_index()
healthySurfing.head()
# Out:
#    index CACode VaCode Estimate  ASE Flag
# 0      0   C01T   V01A     18.9  0.9  NaN
# 1      1   C01T   V01B       19  1.1  NaN
# 2      2   C01T   V01C     30.3  1.0  NaN
# 3      3   C01T   V01D     14.9  1.0  NaN
# 4      4   C01T   V01E       17  1.0  NaN

# %%
#read the csv 
#combine surfing forecast with health data into one dataframe
#load data into database

#df1.merge(df2, left_on='lkey', right_on='rkey',
          suffixes=('_left', '_right'))
# Out:
#   File "<ipython-input-30-85afbf839870>", line 6
#     suffixes=('_left', '_right'))
#     ^
# IndentationError: unexpected indent

# %%
#FridayWaves_df.merge(healthySurfing)

#pd.merge(df1, df2, left_index=True, right_index=True)
#df1.join(df2)
#pd.concat([df1, df2], axis=1)

OuterJoin_df = pd.concat([FridayWaves_df, healthySurfing], axis=1)
OuterJoin_df.head()
# Out:
#      Unnamed: 0          Surf  Swell Rating Primary Swell Primary Swell.1  \
# 0  Monday 02/24  Monday 02/24  Monday 02/24  Monday 02/24    Monday 02/24
# 1           NaN           NaN           NaN           NaN             NaN
# 2           NaN           NaN           NaN           NaN             NaN
# 3           NaN           NaN           NaN           NaN             NaN
# 4           NaN           NaN           NaN           NaN             NaN
#
#   Primary Swell.2 Secondary Swell Secondary Swell.1 Secondary Swell.2  \
# 0    Monday 02/24    Monday 02/24      Monday 02/24      Monday 02/24
# 1             NaN             NaN               NaN               NaN
# 2             NaN             NaN               NaN               NaN
# 3             NaN             NaN               NaN               NaN
# 4             NaN             NaN               NaN               NaN
#
#   Secondary Swell.3  ...   Unnamed: 18   Unnamed: 19   Unnamed: 20  \
# ...

# %%
LeftJoin_df = healthySurfing.join(FridayWaves_df)
LeftJoin_df.head()
# Out:
#    index CACode VaCode Estimate  ASE Flag    Unnamed: 0          Surf  \
# 0      0   C01T   V01A     18.9  0.9  NaN  Monday 02/24  Monday 02/24
# 1      1   C01T   V01B       19  1.1  NaN           NaN           NaN
# 2      2   C01T   V01C     30.3  1.0  NaN           NaN           NaN
# 3      3   C01T   V01D     14.9  1.0  NaN           NaN           NaN
# 4      4   C01T   V01E       17  1.0  NaN           NaN           NaN
#
#    Swell Rating Primary Swell  ...          Wind        Wind.1       Weather  \
# 0  Monday 02/24  Monday 02/24  ...  Monday 02/24  Monday 02/24  Monday 02/24
# 1           NaN           NaN  ...           NaN           NaN           NaN
# 2           NaN           NaN  ...           NaN           NaN           NaN
# 3           NaN           NaN  ...           NaN           NaN           NaN
# 4           NaN           NaN  ...           NaN           NaN           NaN
#
#       Weather.1         Prob.   Unnamed: 17   Unnamed: 18   Unnamed: 19  \
# ...

# %% [markdown]
# #get this data loaded into a database

# %%
# !pip install psycopg2
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/84/d7/6a93c99b5ba4d4d22daa3928b983cec66df4536ca50b22ce5dcac65e4e71/psycopg2-2.8.4.tar.gz
#     ERROR: Command errored out with exit status 1:
#      command: /Applications/anaconda3/envs/pythondata/bin/python -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/wv/qty1vbcs52l5lqlqscdj6kk40000gn/T/pip-install-rf978drn/psycopg2/setup.py'"'"'; __file__='"'"'/private/var/folders/wv/qty1vbcs52l5lqlqscdj6kk40000gn/T/pip-install-rf978drn/psycopg2/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/wv/qty1vbcs52l5lqlqscdj6kk40000gn/T/pip-install-rf978drn/psycopg2/pip-egg-info
#          cwd: /private/var/folders/wv/qty1vbcs52l5lqlqscdj6kk40000gn/T/pip-install-rf978drn/psycopg2/
#     Complete output (23 lines):
#     running egg_info
# ...

# %%
#create sqlalchemy engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="postgres",
                               pw="postgres",
                               db="HealthySurfingDB"))

# %%
# connect with DBMS
engine = create_engine('postgresql://postgres:postgres@localhost:5432/HealthySurfingDB')
LeftJoin_df.to_sql('HealthSurf', engine)
