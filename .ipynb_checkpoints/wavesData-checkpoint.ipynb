# %%
#import dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd
import os

# %%
# URL of page to be scraped
#https://magicseaweed.com/Deal-Surf-Report/822/

# %%
df = pd.read_html('https://magicseaweed.com/Deal-Surf-Report/822/')
len(df)
# Out:
# 17

# %%
df[0]
# Out:
#       0        1        2
# 0   Low  12:48AM   -0.1ft
# 1  High   7:05AM   4.89ft
# 2   Low   1:19PM  -0.33ft
# 3  High   7:28PM   4.33ft

# %%
df[1]
# Out:
#              0       1
# 0  First Light  6:09AM
# 1      Sunrise  6:36AM
# 2       Sunset  5:42PM
# 3   Last Light  6:09PM

# %%
df[2]
# Out:
#        Unnamed: 0          Surf  Swell Rating Primary Swell Primary Swell.1  \
# 0    Sunday 02/23  Sunday 02/23  Sunday 02/23  Sunday 02/23    Sunday 02/23
# 1            12am           1ft           NaN           1ft              8s
# 2             3am         1-2ft           NaN         1.4ft              9s
# 3             6am         1-2ft           NaN         1.4ft              9s
# 4             9am         1-2ft           NaN         1.4ft              9s
# ..            ...           ...           ...           ...             ...
# 121          High       11:05PM         4.1ft           NaN             NaN
# 122   First Light        6:00AM           NaN           NaN             NaN
# 123       Sunrise        6:27AM           NaN           NaN             NaN
# 124        Sunset        5:48PM           NaN           NaN             NaN
# 125    Last Light        6:16PM           NaN           NaN             NaN
#
# ...

# %%
FridayWaves_df = df[2]

# %%
null_columns=FridayWaves_df.columns[FridayWaves_df.isnull().any()]

# %%
FridayWaves_df[null_columns].isnull().sum()
# Out:
# Swell Rating          84
# Primary Swell         56
# Primary Swell.1       56
# Primary Swell.2      112
# Secondary Swell       56
# Secondary Swell.1     56
# Secondary Swell.2    112
# Secondary Swell.3     74
# Secondary Swell.4     74
# Secondary Swell.5    112
# Wind                  56
# Wind.1               112
# Weather              112
# Weather.1             56
# Prob.                 56
# Unnamed: 17          112
# Unnamed: 18          112
# Unnamed: 19          112
# Unnamed: 20          112
# Unnamed: 21          112
# dtype: int64

# %%
FridayWaves_df=FridayWaves_df.dropna()
FridayWaves_df
# Out:
#                                             Unnamed: 0  \
# 0                                         Sunday 02/23
# 9    Tide and daylight times for Belmar, Atlantic O...
# 18                                        Monday 02/24
# 27   Tide and daylight times for Belmar, Atlantic O...
# 36                                       Tuesday 02/25
# 45   Tide and daylight times for Belmar, Atlantic O...
# 54                                     Wednesday 02/26
# 63   Tide and daylight times for Belmar, Atlantic O...
# 72                                      Thursday 02/27
# 81   Tide and daylight times for Belmar, Atlantic O...
# 90                                        Friday 02/28
# 99   Tide and daylight times for Belmar, Atlantic O...
# 108                                     Saturday 02/29
# 117  Tide and daylight times for Belmar, Atlantic O...
#
#                                                   Surf  \
# 0                                         Sunday 02/23
# ...

# %%
FridayWaves_df.reset_index()
# Out:
#     index                                         Unnamed: 0  \
# 0       0                                       Sunday 02/23
# 1       9  Tide and daylight times for Belmar, Atlantic O...
# 2      18                                       Monday 02/24
# 3      27  Tide and daylight times for Belmar, Atlantic O...
# 4      36                                      Tuesday 02/25
# 5      45  Tide and daylight times for Belmar, Atlantic O...
# 6      54                                    Wednesday 02/26
# 7      63  Tide and daylight times for Belmar, Atlantic O...
# 8      72                                     Thursday 02/27
# 9      81  Tide and daylight times for Belmar, Atlantic O...
# 10     90                                       Friday 02/28
# 11     99  Tide and daylight times for Belmar, Atlantic O...
# 12    108                                     Saturday 02/29
# 13    117  Tide and daylight times for Belmar, Atlantic O...
#
# ...

# %%
FridayWaves_df.describe()
# Out:
#           Unnamed: 0          Surf  Swell Rating Primary Swell  \
# count             14            14            14            14
# unique            14            14            14            14
# top     Friday 02/28  Friday 02/28  Friday 02/28  Friday 02/28
# freq               1             1             1             1
#
#        Primary Swell.1 Primary Swell.2 Secondary Swell Secondary Swell.1  \
# count               14              14              14                14
# unique              14              14              14                14
# top       Friday 02/28    Friday 02/28    Friday 02/28      Friday 02/28
# freq                 1               1               1                 1
#
#        Secondary Swell.2 Secondary Swell.3  ...          Wind        Wind.1  \
# count                 14                14  ...            14            14
# unique                14                14  ...            14            14
# ...

# %%
#import and read csv on well being and health data
#is there some correlation between surfing and well being?

# %%
healthySurfing = pd.read_csv("well-being-statistics.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-8efa8c0faa70> in <module>
# ----> 1 healthySurfing = pd.read_csv("well-being-statistics.csv")
#
# /Applications/anaconda3/envs/pythondata/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
#read the csv 
#combine surfing forecast with health data into one dataframe
#load data into database
